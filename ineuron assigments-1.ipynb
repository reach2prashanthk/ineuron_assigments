# %% [markdown]
# # ineuron assignment1

# %% [markdown]
# #1. In the below elements which of them are values or an expression? eg:- values can be
# #integer or string and expressions will be mathematical operators.
#
# 1) *  is an  expression
# 2) 'hello' is a string value
# 3) -87.8 is  a value
# 4)- is an expression
# 5) / is an expression
# 6) + is an expression
# 7)  is a value
#
#
# 2) What is the difference between string and variable?
#
# Ans: A string is a sequence of characters enclosed in either single    quotes' ' or double quotes, strings are used whenever we         represent textual form of data ex: my_string = "Hello, World!"
#
#
# 3) Describe three different data types.
#
# Ans: Numeric type
#
#      int=Represents whole numbers, such as 1, 2, -3, etc.
#      float=Represents decimal numbers, such as 3.14, -0.5, etc.
#      complex=Represents numbers in the form of a + bj, where a and b are floats, and j is the imaginary unit.
#
#      Boolean Type: Represents either True or False, used for logical operations and conditional statements.
#
#
#      Sequence Types:
#
#      List=an ordered collection of items enclosed in square brackets, can contain elements of different types.ex=list=                     [1,2,3,'hello',5]
#      Tuple: contains an ordered immutable collection of itemsenclosed by parenthesis
#             ex_tuple=(1,2,3,'prashanth')
#
#
#      Text Type:String (str): Represents a sequence of characters enclosed in quotes, such as "Hello, World!".
#
#
#
# 4. What is an expression made up of? What do all expressions do?
# Ans: an expression is a combination of literals,variables,operators,literals,operators, and a function call which can be evaluated to produce a value
# Ex: sum=1+2+3
#
#
#  5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
# Ans: expressions are used to compute values while statements like spam=10 is used to hold the value '10' on variable name 'spam'
#  we can use this statement as an expression like sum=spam+10      where sum will be 20
#
#
# 6. After running the following code, what does the variable bacon contain?bacon = 22, bacon + 1
#
# Ans: bacon contains 23 since its value increased by 1
#
# 7. What should the values of the following two terms be?'spam'+'spamspam'   and 'spam'*3
#
# Ans: since 'spam' is a string and do not contacin any variable
#
# 'spam'+'spamspam'='spamspamspam'
#
# 'spam'*3='spamspamspam'
#
#
# 8. Why is eggs a valid variable name while 100 is invalid?
#
#
# ans:  Python allows the use of descriptive words or phrases as    variable names  as long as variable do not contacin any reserverd words
# while 100 is an  invalid variable name because it starts with a digit, Variable names must start with a letter or an underscore
#
#
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
#
# ans: int(),float(),str()
#      ex: value=10
#          int(value)=10
#          float(value)=10.0
#          str(value)='10'
#
#
#
# 10. Why does this expression cause an error? How can you fix it?
#  'i have eaten'+99+'burritos'
#
# Ans: this will cause an error 'TypeError: can only concatenate str (not "int") to str'
#
# enclosing 99 under quotes will execute the result 'i have eaten99burritos'

# %% [markdown]
# #  ineuron assignment2
