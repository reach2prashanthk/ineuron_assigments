# %% [markdown]
# # ineuron assignment 3

# %% [markdown]
# 1. Why are functions advantageous to have in your programs?
# Ans:
# Functions reduce the need for duplicate code,By including functions, we can prevent repeating the same code block repeatedly in a program.
#
# Functions can be written in a way that promotes reusability across different projects or parts of the same project
#
# By breaking a program into smaller functions, each responsible for a specific task, you can better organize and manage the codebase
#
#
# Code Readability:Functions are helpful in understanding the code by dividing a large program into smaller and meaningful sections
#
#
#
# 2. When does the code in a function run: when it's specified or when it's called?
#
# The code in a function runs when the function is called
#
#
# 3. What statement creates a function?
#
#
# typically called a "function definition", In Python, the def statement is used to define a function.
# ex: def function_name(parameters):
#                 # Code block or statements
#                 that make up the function's body
#
# 4. What is the difference between a function and a function call?
#
# Ans: for ex: def function(name):
#     print("Hello, " + name + "!")
#     #functin defined but not executed
#
#
# function("Prashanth")
# #calling function
#
# function is a named block of reusable code that performs a specific task of actions.
# function call is the instruction that triggers the execution of the statements within the function's code block.
#
#
# 5. How many global scopes are there in a Python program? How many local scopes?
#
# global scope: It is the scope in which variables and functions are defined outside of any specific function or class, typically python has one global scope
#
# Local scope: it contain variables that are defined within the function or method and are accessible only within that particular scope.multiple local scopes can exist if multiple functions are called as these are temporarily created
#
#
#
#
# glob_variable = 100  #  variable defined in the global scope
#
# def _function():
#     loc_variable = 50 # Local variable defined in the local scope of the function
#     print(loc_variable)  # Accessing the local variable
#     print(glob_variable)  # Accessing the global variable
#
# _function()  # Function call
#
#
# 6. What happens to variables in a local scope when the function call returns?
# Ans: These are created when the function is called and exist only as long as the function is executing
#  Once the function call returns and the execution leaves the code block the locl scope will get deleted
#
#
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?
#
# Ans: when return statement is executed  during the function's execution, the function exits immediately, and the specified value is passed back to the caller.
#
# usually return statement returns the value like below ex:
# def add_sum(a,b):
#   sum=a+b
#   return sum #which will fetch the sum of two variables a and b
#
# result=add_sum(2,3)
# print(result) # which will fetch result 5
#
#
# Its possible to have a return value in an expression  per below ex:
# def cube(a):
#     return x*x*x
#
# result = cube(5)+cube(4) #this result value is result of calling the function twice and adds the final result will be 189
# print(result)
#
#
#
# 8. If a function does not have a return statement, what is the return value of a call to that function?
#
# Ans: the return value of a call to that function is None.
#
# for ex def my_function(name):
#            print('hello'+name+'!')
#
# result=my_function(prashanth)
# print(result)
#
# there is no explicit return statement, when function is called with argument 'prashanth' but still prints due to print statement associated with it
#
#
# 9. How do you make a function variable refer to the global variable?
#
# Ans: we can use the global keyword in Python.
#      for ex:
#     global_varible=100
# def my_function():
#     global global_variable
#     global_variable=20
#
# print(global_varible) #output is 100
#
# my_function()
# print(global_variable) #ouput is 20
#
# global keyword is used to indicate that the variable global_variable refers to the global variable rather than creating a new local variable.
#
# 10. What is the data type of None?
#
# Ans: None in Python is NoneType. None is a special value in Python that represents the absence of a value or a null value.
#
# ex: result=None
# print(type(None)) # prints  #<class 'NoneType'>
#
#
# 11. What does the sentence import areallyourpetsnamederic do?
#
# Ans: This Will  'result in a ModuleNotFoundError'
#      if the areallyourpetsnamederic module is available in python the import statement will import the entire module
#
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
# Ans: after importing spam module, we'll call th bacon() feature as
#
# ex: import spam
#     spam.bacon()
#
#
# 13. What can you do to save a programme from crashing if it encounters an error?
#
# Ans: we need to use error handling techniques such as Try-Except Blocks and use 'Logging' feature to capture the information about error
#
# 14. What is the purpose of the try clause? What is the purpose of the except clause?
#
# Ex: Try clause is a block code where we seek the possibiliy of occurance of error, by enclosing the code within try clause we're instructing python to check the code for an error anf if occurs immediately transfer the control to except clause
#
#     except clause allows you to catch and handle exceptions within     controlled environment
#
#
# ex: try:
#      Code that might cause an exception
#     result = 1 / 0  # Division by zero - ZeroDivisionError
# except ZeroDivisionError:
#     # Code to handle the ZeroDivisionError exception
#     print("Divide by zero is not allowed enter an integer.")
#
#
# By using the try and except clauses together, we  can monitor and handle exceptions, allowing  program to handle errors  and continue execution rather than crashing.

# %%
# Out:
# <class 'NoneType'>
